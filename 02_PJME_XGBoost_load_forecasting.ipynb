# %%
#真正的对比价值在跑两个模型时对比训练时间、内存、特征重要性的一致性、超参敏感度——这是工程师视角，比"集成 RMSE 降了 0.5%"更值得放进项目讲解。
#气象数据接入、MAPE 分时段分析、**probabilistic forecasting（分位数回归输出预测区间）**这些有"工程实战感"和"业务感知"的部分。
#光伏功率预测（带 NWP 数值天气预报输入，更接近真实业务）或者电力市场价格预测（heavy-tail 分布，loss function 选择有讲究）。

# %%
import pandas as pd

# %%
folder_path = '/Users/gtw/Desktop/新能源/负荷/archive-2/PJME_hourly.csv'

# %%
df = pd.read_csv(folder_path, parse_dates = ['Datetime'], index_col = 0)

# %%
#Feature Extraction
